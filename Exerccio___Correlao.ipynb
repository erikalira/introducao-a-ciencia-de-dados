# %% [markdown]
# <a href="https://colab.research.google.com/github/erikalira/introducao-a-ciencia-de-dados/blob/main/Exerccio___Correlao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução à Ciência de Dados - UFPB
# Professor: Yuri Malheiros
#
# ## Correlação

# %% [markdown]
# Colete os seguintes dados dos times do campeonato brasileiro de 2020:
#
# - Pontos
# - Gols marcados
# - Gol sofridos
#
# Você pode encontrar esses dados no site da CBF (www.cbf.com.br)
#
# Calcule a correlação entre:
#
# - Pontos e gols marcados
# - Pontos e gols sofridos

# %% [markdown]
# ### Correlação entre Pontos e gols marcados

# %%
import pandas as pd

brasileirao_df = pd.read_csv("tabela_brasileirao_2020.csv")
brasileirao_df
# Out:
#    Posição  Posições ganhas                  Time Estado  ...  SG   CA  CV   %
# 0       1º                0              Flamengo     RJ  ...  20   90   4  62
# 1       2º                0         Internacional     RS  ...  26   91   9  61
# 2       3º                0              Atlético     MG  ...  19   72   6  59
# 3       4º                0             São Paulo     SP  ...  18   95   2  57
# 4       5º                0            Fluminense     RJ  ...  13   85   5  56
# 5       6º                0                Grêmio     RS  ...  13   70   8  51
# 6       7º                0             Palmeiras     SP  ...  14   96   5  50
# 7       8º                0                Santos     SP  ...   1   86   6  47
# 8       9º                0  Athletico Paranaense     PR  ...   2   82   5  46
# 9      10º                1   Red Bull Bragantino     SP  ...  10   81   4  46
# 10     11º                1                 Ceará     CE  ...   3   91  10  45
# ...

# %%
# ADICIONE O SEU CÓDIGO AQUI
brasileirao_df[["PTS", "GP"]].corr()
# Out:
#           PTS        GP
# PTS  1.000000  0.905261
# GP   0.905261  1.000000

# %% [markdown]
# ### Correlação entre Pontos e gols sofridos

# %%
# ADICIONE O SEU CÓDIGO AQUI
brasileirao_df[["PTS", "GC"]].corr()
# Out:
#           PTS        GC
# PTS  1.000000 -0.708773
# GC  -0.708773  1.000000

# %% [markdown]
# ### Análise dos Resultados
#
# Qual o nível (fraco, moderado, forte) das correlações entre as variáveis analisadas?

# %% [markdown]
# R:  Pontos e gols marcados tem correlação muito forte. Ja Pontos e gols sofridos tem correlação forte.

# %% [markdown]
# De acordo com os dados analisados, é melhor um time focar em marcar mais gols ou sofrer menos gols?

# %% [markdown]
# r: é melhor o time focar em marcar mais gols!
